# %%
daddy=[[3885,  404,    0,  612],
[ 723, 3320,  857,    1],
[  24,  867, 3958,    0],
[ 431,    0,    0, 4558]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(daddy, cmap="Blues",xticklabels=['3G_backhaul', '4G_backhaul','4G_RAN','   NC'], yticklabels=['3G_backhaul', '4G_backhaul', '4G_RAN','NC'])
